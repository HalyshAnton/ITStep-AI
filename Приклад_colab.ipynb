# %% [markdown]
# <a href="https://colab.research.google.com/github/HalyshAnton/ITStep-AI/blob/superwised_learning/%D0%9F%D1%80%D0%B8%D0%BA%D0%BB%D0%B0%D0%B4_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "John"
age = 30

print(name, age)
# Out:
# John 30

# %%
print(age)
# Out:
# 34

# %%
age += 1

# %%
print(age)
# Out:
# 30
