# %% [markdown]
# <a href="https://colab.research.google.com/github/HalyshAnton/ITStep-AI/blob/superwised_learning/%D0%94%D0%97_%D0%B4%D0%B5%D1%80%D0%B5%D0%B2%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/House_Rent_Dataset.csv", index_col="Unnamed: 0")
df = df.drop(columns="Posted On")

# %% [markdown]
# [Ігформація про дані](https://www.kaggle.com/datasets/iamsouravbanerjee/house-rent-prediction-dataset)

# %%
df.head()
# Out:
#    BHK     Rent    Size            Floor    Area Type  \
# 0  2.0  10000.0  1100.0  Ground out of 2          NaN
# 1  2.0  20000.0   800.0       1 out of 3   Super Area
# 2  2.0  17000.0  1000.0       1 out of 3   Super Area
# 3  2.0  10000.0   800.0       1 out of 2   Super Area
# 4  2.0   7500.0   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                       NaN  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4                       NaN  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0       2.0    Contact Owner
# 1       1.0              NaN
# 2       1.0    Contact Owner
# 3       1.0    Contact Owner
# 4       1.0    Contact Owner

# %% [markdown]
# # Завдання 1
# * Очистіть дані від викидів
# * Отримайте ознаки та цільову змінну(X, y)
# * Розділіть дані на тренувальні та тестові

# %% [markdown]
# # Завдання 2
# Створіть Pipeline для обробки даних числових та категоріальних даних

# %% [markdown]
# # Завдання 3
# Об'єднайте препроцесор з деревом рішень в один пайплайн

# %% [markdown]
# # Завдання 4
# Виведіть основні метрики моделі

# %% [markdown]
# # Завдання 5
# Змініть параметри моделі та попробуйте покращити результат та натренуйте його

# %% [markdown]
# # Завдання 6
# Спрогнозуйте ціну оренди на тестових даних та порівняйте зі справжніми
