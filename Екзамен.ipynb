# %% [markdown]
# <a href="https://colab.research.google.com/github/HalyshAnton/ITStep-AI/blob/exam/%D0%95%D0%BA%D0%B7%D0%B0%D0%BC%D0%B5%D0%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Загальні умови
#
# Студент обирає одне завдання на вибір, або узгоджує власний проект з викладачем. Студент повен показати розуміння усіх технологій який він\вона використали для завдання.
#
# Студент самостійно пише увесь код до початку екзамену. Під час екзамену кожен студент презентує свою роботу викладачу та відповідає на основні питання, що стосуються проекту, також можуть бути додаткові питання на кристалики\більші бали.

# %% [markdown]
# # Завдання 1
#
# Створіть застосунок керування показом презентації за допомогою жестів.
# Презентацію показуйте за допомогою *opencv* використавуючии [кадри](https://github.com/HalyshAnton/ITStep-AI/tree/exam/data/exam/hands)
#
# Надайте можливість користувачу малювати лінії певного кольору підч ас показу слайдів.
#
# Для цього
# * користувач має користуватися відеокамерою
# * коли користувач зробить жест, покажіть кадром з презентації
# * створіть окреме зображення "полотно" чорного кольору(розмір як і в кадрах презентації)
# * коли у користувача підняті 2 пальці правої руки: намалюйте коло на "полотні" з центром де знаходяться пальці обраного кольору
# * створіть маску для полотна з умовою не чорний
# * замініть усі пікселі на слайді які відповідають масці на відповідні пікселі з полотна
#
# **Функціонал:**
# * Відкрита долоня (всі пальці вверх)	-- Почати показ презентації та очистити полотно
# * Один вказівний палець вверх -- Наступний слайд
# * великий палець вбік  --	Попередній слайд
# * Вказівний та середній вверх --	Почати малювання
# * Вказівний та середній вверх, великий вбік --	Змінити колір малювання (червоний → зелений → синій → червоний → ... кольори змінюються поколу )
#
# Через те що модель може працювати нестабільно, робіть зміну лише якщо жест триває довше за 1 секунду
#
#
# <br>
#
# **Доступні кольори:** червоний, зелений, синій
#
# <br>
# <br>
#
# **Додадково:**  реалізуйте  гумку для стирання

# %% [markdown]
# ## поради до виконання

# %%
# віддзеркальте зображення, щоб легше було орієнтуватись
cv2.flip

# %%
# очистіть шуми для кращої детекції
cv2.medianBlur

# %%
# для визначення положення пальців краще підійде содель з mediapipe
import mediapipe as mp

mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)

rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
result = hands.process(rgb_frame)

if result.multi_hand_landmarks:
    for hand_landmarks in result.multi_hand_landmarks:

# %%
# для малювання більш стабільних ліній, малюйте не кола,
# а лінії між останнім та нинішнім положенням вказівного пальця
cv2.line(canvas, curent_point, last_point, color, thickness)

# %% [markdown]
# # Завдання 2
#
#
# Напишіть чат-бота для роботи лікарні. У чат-бота має бути 2 основних інструмента:
# * доступ до векторної бази даних з документами
# * доступ до реляційної бази даних(SQL)
#
# <br>
#
# **Векторна база даних**
#
# Створіть векторну базу даних на *Pineconne* з [документами](https://github.com/HalyshAnton/ITStep-AI/tree/exam/data/exam/hospital). Виконайте наступні кроки
# * прочитайте вміст кожного документа
# * розбийте його на розділи
# * добавте до метеданих поточний час
# * добавте кожен розділ у векторну бд
# * збережіть ID з назвами розділів та назвами файлів
#
# <br>
#
# **Реляційна база даних**
#
# Створіть реляційну базу даних на [Supabase](https://supabase.com/), використайте SQL запити з практичних по базах даних цього курсу.
# База даних має містити декілька таблиць та зв'язки між ними.
#
# Створіть інструмент для агента за допомогою [SQLDatabase](https://python.langchain.com/docs/integrations/tools/sql_database/)
#
# Створіть додаток вашого чат бота за допомогою *streamlit*

# %% [markdown]
# ## підключення

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (![image.png](data:image/png;base64,...))

# %% [markdown]
# ![image.png](data:image/png;base64,...)
